# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
from sklearn import tree

print("📌 Entrenando modelo Árbol de Decisión...")

# Entrenar modelo
clf_tree = DecisionTreeClassifier(random_state=42)
clf_tree.fit(X_train, y_train)

# Predicciones
y_pred_tree = clf_tree.predict(X_test)

print("\n✅ Modelo entrenado. Evaluando resultados...\n")

# Matriz de confusión
print("🔍 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred_tree))

# Reporte de clasificación
print("\n📋 Reporte de Clasificación:")
print(classification_report(y_test, y_pred_tree, target_names=["Comestible", "Venenoso"]))

# Precisión global
acc = accuracy_score(y_test, y_pred_tree)
print(f"\n🎯 Precisión del modelo (accuracy): {acc:.4f}")

# Visualización del árbol
print("\n🌳 Mostrando gráfico del Árbol de Decisión...")
plt.figure(figsize=(20, 10))
tree.plot_tree(clf_tree,
               feature_names=X.columns,
               class_names=["Comestible", "Venenoso"],
               filled=True,
               rounded=True,
               fontsize=10)
plt.title("Árbol de Decisión - Clasificación de Hongos")
plt.show()
# Out:
# 📌 Entrenando modelo Árbol de Decisión...
#
# ✅ Modelo entrenado. Evaluando resultados...
#
# 🔍 Matriz de Confusión:
# [[1 0]
#  [0 2]]
#
# 📋 Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#   Comestible       1.00      1.00      1.00         1
#     Venenoso       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# 🎯 Precisión del modelo (accuracy): 1.0000
#
# 🌳 Mostrando gráfico del Árbol de Decisión...
